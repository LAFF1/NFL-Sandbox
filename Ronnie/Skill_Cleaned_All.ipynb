# %% [markdown]
# # Skill Position Players NFL 2019, 2020, 2021 Data Munging and Transformation by Skill Position

# %%
# importing pandas
import pandas as pd
  
# merging two csv files
df = pd.concat(
    map(pd.read_csv, ['data/NFL_1.csv', 'data/NFL_2.csv', 'data/NFL_3.csv']), ignore_index=True)

# %%
df.head(5)
# Out:
#    Unnamed: 0               Player   Tm Pos  Age   G  GS    Tgt    Rec  \
# 0         0.0  Christian McCaffrey  CAR  RB   23  16  16  142.0  116.0
# 1         1.0        Lamar Jackson  BAL  QB   22  15  15    0.0    0.0
# 2         2.0        Derrick Henry  TEN  RB   25  15  15   24.0   18.0
# 3         3.0          Aaron Jones  GNB  RB   25  16  16   68.0   49.0
# 4         4.0      Ezekiel Elliott  DAL  RB   24  16  16   71.0   54.0
#
#    PassingYds  ...  RushingTD  RushingAtt  ReceivingYds  ReceivingTD  \
# 0         0.0  ...       15.0       287.0        1005.0          4.0
# 1      3127.0  ...        7.0       176.0           0.0          0.0
# 2         0.0  ...       16.0       303.0         206.0          2.0
# 3         0.0  ...       16.0       236.0         474.0          3.0
# 4         0.0  ...       12.0       301.0         420.0          2.0
#
#    FantasyPoints  Int  Fumbles  FumblesLost   Year   Year
# 0         469.20  0.0      1.0          0.0  2019.0   NaN
# 1         415.68  6.0      9.0          2.0  2019.0   NaN
# 2         294.60  0.0      5.0          3.0  2019.0   NaN
# 3         314.80  0.0      3.0          2.0  2019.0   NaN
# 4         311.70  0.0      3.0          2.0  2019.0   NaN
#
# [5 rows x 23 columns]

# %%
# Shape is just an attribute that tells us the shape of our DataFrame in the format (rows, columns)
print(df.shape) 
print('We have', df.shape[0], 'players we can analyze for the 2021 season')
print('We have', df.shape[1], 'columns of data we can analyze for the 2021 season')
# Out:
# (1917, 23)
# We have 1917 players we can analyze for the 2021 season
# We have 23 columns of data we can analyze for the 2021 season

# %%
# Displaying columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Tm', 'Pos', 'Age', 'G', 'GS', 'Tgt', 'Rec',
#        'PassingYds', 'PassingTD', 'PassingAtt', 'RushingYds', 'RushingTD',
#        'RushingAtt', 'ReceivingYds', 'ReceivingTD', 'FantasyPoints', 'Int',
#        'Fumbles', 'FumblesLost', 'Year ', 'Year'],
#       dtype='object')

# %%
# 2022 NFL RB Draft Order Data Frame 
main_df = df[['Player', 'Tm', 'Pos', 'Tgt', 'Rec', 'GS', 'ReceivingYds', 'RushingYds', 'RushingTD', 'RushingAtt', 'ReceivingTD', 'FantasyPoints', 'Year']]
main_df.head(10)
# Out:
#                 Player   Tm Pos    Tgt    Rec  GS  ReceivingYds  RushingYds  \
# 0  Christian McCaffrey  CAR  RB  142.0  116.0  16        1005.0      1387.0
# 1        Lamar Jackson  BAL  QB    0.0    0.0  15           0.0      1206.0
# 2        Derrick Henry  TEN  RB   24.0   18.0  15         206.0      1540.0
# 3          Aaron Jones  GNB  RB   68.0   49.0  16         474.0      1084.0
# 4      Ezekiel Elliott  DAL  RB   71.0   54.0  16         420.0      1357.0
# 5          Dalvin Cook  MIN  RB   63.0   53.0  14         519.0      1135.0
# 6       Michael Thomas  NOR  WR  185.0  149.0  15        1725.0        -9.0
# 7         Travis Kelce  KAN  TE  136.0   97.0  16        1229.0         4.0
# 8           Nick Chubb  CLE  RB   49.0   36.0  16         278.0      1494.0
# 9        Austin Ekeler  LAC  RB  108.0   92.0   8         993.0       557.0
#
#    RushingTD  RushingAtt  ReceivingTD  FantasyPoints  Year
# 0       15.0       287.0          4.0         469.20   NaN
# 1        7.0       176.0          0.0         415.68   NaN
# 2       16.0       303.0          2.0         294.60   NaN
# 3       16.0       236.0          3.0         314.80   NaN
# 4       12.0       301.0          2.0         311.70   NaN
# 5       13.0       250.0          0.0         292.40   NaN
# 6        0.0         1.0          9.0         374.60   NaN
# 7        1.0         1.0          5.0         254.30   NaN
# 8        8.0       298.0          0.0         255.20   NaN
# 9        3.0       132.0          8.0         309.00   NaN

# %%
# Changing column names from  G to Games (Played) and AVG to (ADP) Average Draft Position and viewing
main_df = main_df.rename(columns={'Tm':'Team', 'GS':'Games'})
main_df.head(10)
# Out:
#                 Player Team Pos    Tgt    Rec  Games  ReceivingYds  \
# 0  Christian McCaffrey  CAR  RB  142.0  116.0     16        1005.0
# 1        Lamar Jackson  BAL  QB    0.0    0.0     15           0.0
# 2        Derrick Henry  TEN  RB   24.0   18.0     15         206.0
# 3          Aaron Jones  GNB  RB   68.0   49.0     16         474.0
# 4      Ezekiel Elliott  DAL  RB   71.0   54.0     16         420.0
# 5          Dalvin Cook  MIN  RB   63.0   53.0     14         519.0
# 6       Michael Thomas  NOR  WR  185.0  149.0     15        1725.0
# 7         Travis Kelce  KAN  TE  136.0   97.0     16        1229.0
# 8           Nick Chubb  CLE  RB   49.0   36.0     16         278.0
# 9        Austin Ekeler  LAC  RB  108.0   92.0      8         993.0
#
#    RushingYds  RushingTD  RushingAtt  ReceivingTD  FantasyPoints  Year
# 0      1387.0       15.0       287.0          4.0         469.20   NaN
# 1      1206.0        7.0       176.0          0.0         415.68   NaN
# 2      1540.0       16.0       303.0          2.0         294.60   NaN
# 3      1084.0       16.0       236.0          3.0         314.80   NaN
# 4      1357.0       12.0       301.0          2.0         311.70   NaN
# 5      1135.0       13.0       250.0          0.0         292.40   NaN
# 6        -9.0        0.0         1.0          9.0         374.60   NaN
# 7         4.0        1.0         1.0          5.0         254.30   NaN
# 8      1494.0        8.0       298.0          0.0         255.20   NaN
# 9       557.0        3.0       132.0          8.0         309.00   NaN

# %% [markdown]
# # 2019, 2021, 2022 NFL Running Back Data

# %%
# Running Back Featured Columns with Usage Ranking and Total Yards From Scrimmage
rb_df = main_df.loc[df['Pos'] == 'RB', ['Player', 'Team', 'Pos','Tgt', 'Rec','RushingAtt', 'RushingYds', 'RushingTD', 'ReceivingYds', 'ReceivingTD','FantasyPoints', 'Games',]]
rb_df['Usage'] = ((df['Tgt'] + df['RushingAtt']) / main_df['Games'])
rb_df['Touchdowns'] = df['RushingTD'] + df['ReceivingTD']
rb_df['TotYdsScrm']= df['ReceivingYds']+ df['RushingYds']
rb_df.head(100)
# Out:
#                   Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  \
# 0    Christian McCaffrey  CAR  RB  142.0  116.0       287.0      1387.0
# 2          Derrick Henry  TEN  RB   24.0   18.0       303.0      1540.0
# 3            Aaron Jones  GNB  RB   68.0   49.0       236.0      1084.0
# 4        Ezekiel Elliott  DAL  RB   71.0   54.0       301.0      1357.0
# 5            Dalvin Cook  MIN  RB   63.0   53.0       250.0      1135.0
# ..                   ...  ...  ..    ...    ...         ...         ...
# 352          T.J. Yeldon  BUF  RB   15.0   13.0        17.0        63.0
# 353          Andrew Beck  DEN  RB   12.0    9.0         1.0         3.0
# 359    Wendell Smallwood  WAS  RB   13.0    9.0        22.0        81.0
# 362         Trey Edmunds  PIT  RB    7.0    6.0        22.0        92.0
# 364            Wes Hills  DET  RB    2.0    2.0        10.0        21.0
#
#      RushingTD  ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  \
# 0         15.0        1005.0          4.0         469.20     16  26.812500
# 2         16.0         206.0          2.0         294.60     15  21.800000
# 3         16.0         474.0          3.0         314.80     16  19.000000
# 4         12.0         420.0          2.0         311.70     16  23.250000
# 5         13.0         519.0          0.0         292.40     14  22.357143
# ..         ...           ...          ...            ...    ...        ...
# 352        0.0         124.0          0.0          29.70      0        inf
# 353        0.0          90.0          1.0          24.54      6   2.166667
# 359        0.0          64.0          0.0          23.50      0        inf
# 362        0.0          48.0          0.0          20.00      0        inf
# 364        2.0           1.0          0.0          16.20      1  12.000000
#
#      Touchdowns  TotYdsScrm
# 0          19.0      2392.0
# 2          18.0      1746.0
# 3          19.0      1558.0
# 4          14.0      1777.0
# 5          13.0      1654.0
# ..          ...         ...
# 352         0.0       187.0
# 353         1.0        93.0
# 359         0.0       145.0
# 362         0.0       140.0
# 364         2.0        22.0
#
# [100 rows x 15 columns]

# %%
# Cleaned RB df dropping na and nan values
rbc_df = rb_df.dropna(thresh=2, axis=1)
rbc_df.head(10)
# Out:
#                  Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  \
# 0   Christian McCaffrey  CAR  RB  142.0  116.0       287.0      1387.0
# 2         Derrick Henry  TEN  RB   24.0   18.0       303.0      1540.0
# 3           Aaron Jones  GNB  RB   68.0   49.0       236.0      1084.0
# 4       Ezekiel Elliott  DAL  RB   71.0   54.0       301.0      1357.0
# 5           Dalvin Cook  MIN  RB   63.0   53.0       250.0      1135.0
# 8            Nick Chubb  CLE  RB   49.0   36.0       298.0      1494.0
# 9         Austin Ekeler  LAC  RB  108.0   92.0       132.0       557.0
# 10          Mark Ingram  BAL  RB   29.0   26.0       202.0      1018.0
# 17         Chris Carson  SEA  RB   47.0   37.0       278.0      1230.0
# 20       Saquon Barkley  NYG  RB   73.0   52.0       217.0      1003.0
#
#     RushingTD  ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  \
# 0        15.0        1005.0          4.0          469.2     16  26.812500
# 2        16.0         206.0          2.0          294.6     15  21.800000
# 3        16.0         474.0          3.0          314.8     16  19.000000
# 4        12.0         420.0          2.0          311.7     16  23.250000
# 5        13.0         519.0          0.0          292.4     14  22.357143
# 8         8.0         278.0          0.0          255.2     16  21.687500
# 9         3.0         993.0          8.0          309.0      8  30.000000
# 10       10.0         247.0          5.0          238.5     15  15.400000
# 17        7.0         266.0          2.0          232.6     15  21.666667
# 20        6.0         438.0          2.0          244.1     13  22.307692
#
#     Touchdowns  TotYdsScrm
# 0         19.0      2392.0
# 2         18.0      1746.0
# 3         19.0      1558.0
# 4         14.0      1777.0
# 5         13.0      1654.0
# 8          8.0      1772.0
# 9         11.0      1550.0
# 10        15.0      1265.0
# 17         9.0      1496.0
# 20         8.0      1441.0

# %%
# Sorted by Average Draft Position
rbc_df.sort_values(by='FantasyPoints', ascending=False).head(25)
# Out:
#                    Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  \
# 0     Christian McCaffrey  CAR  RB  142.0  116.0       287.0      1387.0
# 1246      Jonathan Taylor  IND  RB   51.0   40.0       332.0      1811.0
# 3             Aaron Jones  GNB  RB   68.0   49.0       236.0      1084.0
# 620         Derrick Henry  TEN  RB   31.0   19.0       378.0      2027.0
# 4         Ezekiel Elliott  DAL  RB   71.0   54.0       301.0      1357.0
# 9           Austin Ekeler  LAC  RB  108.0   92.0       132.0       557.0
# 621          Alvin Kamara  NOR  RB  107.0   83.0       187.0       932.0
# 2           Derrick Henry  TEN  RB   24.0   18.0       303.0      1540.0
# 622           Dalvin Cook  MIN  RB   54.0   44.0       312.0      1557.0
# 5             Dalvin Cook  MIN  RB   63.0   53.0       250.0      1135.0
# 1250        Austin Ekeler  LAC  RB   94.0   70.0       206.0       911.0
# 28      Leonard Fournette  JAX  RB  100.0   76.0       265.0      1152.0
# 8              Nick Chubb  CLE  RB   49.0   36.0       298.0      1494.0
# 40           Alvin Kamara  NOR  RB   97.0   81.0       171.0       797.0
# 1256            Joe Mixon  CIN  RB   48.0   42.0       292.0      1205.0
# 20         Saquon Barkley  NYG  RB   73.0   52.0       217.0      1003.0
# 10            Mark Ingram  BAL  RB   29.0   26.0       202.0      1018.0
# 17           Chris Carson  SEA  RB   47.0   37.0       278.0      1230.0
# 1259         Najee Harris  PIT  RB   94.0   74.0       307.0      1200.0
# 22              Joe Mixon  CIN  RB   45.0   35.0       278.0      1137.0
# 1261         James Conner  ARI  RB   39.0   37.0       202.0       752.0
# 23            Todd Gurley  LAR  RB   49.0   31.0       223.0       857.0
# 631       Jonathan Taylor  IND  RB   39.0   36.0       232.0      1169.0
# 37          Miles Sanders  PHI  RB   63.0   50.0       179.0       818.0
# 62           Le'Veon Bell  NYJ  RB   78.0   66.0       245.0       789.0
#
#       RushingTD  ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  \
# 0          15.0        1005.0          4.0         469.20     16  26.812500
# 1246       18.0         360.0          2.0         333.00     17  22.529412
# 3          16.0         474.0          3.0         314.80     16  19.000000
# 620        17.0         114.0          0.0         314.00     16  25.562500
# 4          12.0         420.0          2.0         311.70     16  23.250000
# 9           3.0         993.0          8.0         309.00      8  30.000000
# 621        16.0         756.0          5.0         295.00     10  29.400000
# 2          16.0         206.0          2.0         294.60     15  21.800000
# 622        16.0         361.0          1.0         294.00     14  26.142857
# 5          13.0         519.0          0.0         292.40     14  22.357143
# 1250       12.0         647.0          8.0         274.00     16  18.750000
# 28          3.0         522.0          0.0         259.40     15  24.333333
# 8           8.0         278.0          0.0         255.20     16  21.687500
# 40          5.0         533.0          1.0         248.52      9  29.777778
# 1256       13.0         314.0          3.0         246.00     16  21.250000
# 20          6.0         438.0          2.0         244.10     13  22.307692
# 10         10.0         247.0          5.0         238.50     15  15.400000
# 17          7.0         266.0          2.0         232.60     15  21.666667
# 1259        7.0         467.0          3.0         227.00     17  23.588235
# 22          5.0         287.0          3.0         225.40     15  21.533333
# 1261       15.0         375.0          3.0         221.00      6  40.166667
# 23         12.0         207.0          2.0         217.40     15  18.133333
# 631        11.0         299.0          1.0         217.00     13  20.846154
# 37          3.0         509.0          3.0         216.70     11  22.000000
# 62          3.0         461.0          1.0         213.00     15  21.533333
#
#       Touchdowns  TotYdsScrm
# 0           19.0      2392.0
# 1246        20.0      2171.0
# 3           19.0      1558.0
# 620         17.0      2141.0
# 4           14.0      1777.0
# 9           11.0      1550.0
# 621         21.0      1688.0
# 2           18.0      1746.0
# 622         17.0      1918.0
# 5           13.0      1654.0
# 1250        20.0      1558.0
# 28           3.0      1674.0
# 8            8.0      1772.0
# 40           6.0      1330.0
# 1256        16.0      1519.0
# 20           8.0      1441.0
# 10          15.0      1265.0
# 17           9.0      1496.0
# 1259        10.0      1667.0
# 22           8.0      1424.0
# 1261        18.0      1127.0
# 23          14.0      1064.0
# 631         12.0      1468.0
# 37           6.0      1327.0
# 62           4.0      1250.0

# %%
# Sorted by Fantasy Production
rbc_df['Production'] = ((df['RushingTD'] + df['ReceivingTD'] + df['RushingYds'] + df['ReceivingYds']) / rb_df['Usage'])
rbc_df.head(10)
# Out:
#                  Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  \
# 0   Christian McCaffrey  CAR  RB  142.0  116.0       287.0      1387.0
# 2         Derrick Henry  TEN  RB   24.0   18.0       303.0      1540.0
# 3           Aaron Jones  GNB  RB   68.0   49.0       236.0      1084.0
# 4       Ezekiel Elliott  DAL  RB   71.0   54.0       301.0      1357.0
# 5           Dalvin Cook  MIN  RB   63.0   53.0       250.0      1135.0
# 8            Nick Chubb  CLE  RB   49.0   36.0       298.0      1494.0
# 9         Austin Ekeler  LAC  RB  108.0   92.0       132.0       557.0
# 10          Mark Ingram  BAL  RB   29.0   26.0       202.0      1018.0
# 17         Chris Carson  SEA  RB   47.0   37.0       278.0      1230.0
# 20       Saquon Barkley  NYG  RB   73.0   52.0       217.0      1003.0
#
#     RushingTD  ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  \
# 0        15.0        1005.0          4.0          469.2     16  26.812500
# 2        16.0         206.0          2.0          294.6     15  21.800000
# 3        16.0         474.0          3.0          314.8     16  19.000000
# 4        12.0         420.0          2.0          311.7     16  23.250000
# 5        13.0         519.0          0.0          292.4     14  22.357143
# 8         8.0         278.0          0.0          255.2     16  21.687500
# 9         3.0         993.0          8.0          309.0      8  30.000000
# 10       10.0         247.0          5.0          238.5     15  15.400000
# 17        7.0         266.0          2.0          232.6     15  21.666667
# 20        6.0         438.0          2.0          244.1     13  22.307692
#
#     Touchdowns  TotYdsScrm  Production
# 0         19.0      2392.0   89.920746
# 2         18.0      1746.0   80.917431
# 3         19.0      1558.0   83.000000
# 4         14.0      1777.0   77.032258
# 5         13.0      1654.0   74.562300
# 8          8.0      1772.0   82.074928
# 9         11.0      1550.0   52.033333
# 10        15.0      1265.0   83.116883
# 17         9.0      1496.0   69.461538
# 20         8.0      1441.0   64.955172

# %%
# Plotting the data
from matplotlib import pyplot as plt

plt.style.use('ggplot')

rbc_df.plot(x='Usage', y='Production', kind='scatter')

# %%
rbc_df.to_csv('data/RB_all')

# %% [markdown]
# # 2019, 2020, 2021 NFL WR Data

# %%
# Wide Receiver Featured Columns with Usage Ranking and Total Yards From Scrimmage
wr_df = main_df.loc[df['Pos'] == 'WR', ['Player', 'Team', 'Pos','Tgt', 'Rec','RushingAtt', 'RushingYds', 'RushingTD', 'ReceivingYds', 'ReceivingTD','FantasyPoints', 'Games',]]
wr_df['Usage'] = ((df['Tgt'] + df['RushingAtt']) / main_df['Games'])
wr_df['Touchdowns'] = df['RushingTD'] + df['ReceivingTD']
wr_df['TotYdsScrm']= df['ReceivingYds']+ df['RushingYds']
wr_df.head(10)
# Out:
#              Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  RushingTD  \
# 6    Michael Thomas  NOR  WR  185.0  149.0         1.0        -9.0        0.0
# 14     Chris Godwin  TAM  WR  121.0   86.0         1.0         8.0        0.0
# 19   Kenny Golladay  DET  WR  116.0   65.0         0.0         0.0        0.0
# 25      Cooper Kupp  LAR  WR  134.0   94.0         2.0         4.0        0.0
# 26      Julio Jones  ATL  WR  157.0   99.0         2.0        -3.0        0.0
# 27   DeVante Parker  MIA  WR  128.0   72.0         0.0         0.0        0.0
# 31     Amari Cooper  DAL  WR  119.0   79.0         1.0         6.0        0.0
# 32       Mike Evans  TAM  WR  118.0   67.0         0.0         0.0        0.0
# 33       A.J. Brown  TEN  WR   84.0   52.0         3.0        60.0        1.0
# 34  DeAndre Hopkins  HOU  WR  150.0  104.0         2.0        18.0        0.0
#
#     ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 6         1725.0          9.0         374.60     15  12.400000         9.0
# 14        1333.0          9.0         274.10     14   8.714286         9.0
# 19        1190.0         11.0         248.00     16   7.250000        11.0
# 25        1161.0         10.0         270.50     14   9.714286        10.0
# 26        1394.0          6.0         274.10     15  10.600000         6.0
# 27        1202.0          9.0         246.20     14   9.142857         9.0
# 31        1189.0          8.0         246.50     16   7.500000         8.0
# 32        1157.0          8.0         230.70     13   9.076923         8.0
# 33        1051.0          8.0         217.10     11   7.909091         9.0
# 34        1165.0          7.0         266.54     15  10.133333         7.0
#
#     TotYdsScrm
# 6       1716.0
# 14      1341.0
# 19      1190.0
# 25      1165.0
# 26      1391.0
# 27      1202.0
# 31      1195.0
# 32      1157.0
# 33      1111.0
# 34      1183.0

# %%
# Cleaned WR df dropping na and nan values
wrc_df = wr_df.dropna(thresh=2, axis=1)
wrc_df.head(10)
# Out:
#              Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  RushingTD  \
# 6    Michael Thomas  NOR  WR  185.0  149.0         1.0        -9.0        0.0
# 14     Chris Godwin  TAM  WR  121.0   86.0         1.0         8.0        0.0
# 19   Kenny Golladay  DET  WR  116.0   65.0         0.0         0.0        0.0
# 25      Cooper Kupp  LAR  WR  134.0   94.0         2.0         4.0        0.0
# 26      Julio Jones  ATL  WR  157.0   99.0         2.0        -3.0        0.0
# 27   DeVante Parker  MIA  WR  128.0   72.0         0.0         0.0        0.0
# 31     Amari Cooper  DAL  WR  119.0   79.0         1.0         6.0        0.0
# 32       Mike Evans  TAM  WR  118.0   67.0         0.0         0.0        0.0
# 33       A.J. Brown  TEN  WR   84.0   52.0         3.0        60.0        1.0
# 34  DeAndre Hopkins  HOU  WR  150.0  104.0         2.0        18.0        0.0
#
#     ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 6         1725.0          9.0         374.60     15  12.400000         9.0
# 14        1333.0          9.0         274.10     14   8.714286         9.0
# 19        1190.0         11.0         248.00     16   7.250000        11.0
# 25        1161.0         10.0         270.50     14   9.714286        10.0
# 26        1394.0          6.0         274.10     15  10.600000         6.0
# 27        1202.0          9.0         246.20     14   9.142857         9.0
# 31        1189.0          8.0         246.50     16   7.500000         8.0
# 32        1157.0          8.0         230.70     13   9.076923         8.0
# 33        1051.0          8.0         217.10     11   7.909091         9.0
# 34        1165.0          7.0         266.54     15  10.133333         7.0
#
#     TotYdsScrm
# 6       1716.0
# 14      1341.0
# 19      1190.0
# 25      1165.0
# 26      1391.0
# 27      1202.0
# 31      1195.0
# 32      1157.0
# 33      1111.0
# 34      1183.0

# %%
# Sorted by Average Draft Position
wrc_df.sort_values(by='FantasyPoints', ascending=False).head(10)
# Out:
#                Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  \
# 6      Michael Thomas  NOR  WR  185.0  149.0         1.0        -9.0
# 1247      Cooper Kupp  LAR  WR  191.0  145.0         4.0        18.0
# 14       Chris Godwin  TAM  WR  121.0   86.0         1.0         8.0
# 26        Julio Jones  ATL  WR  157.0   99.0         2.0        -3.0
# 25        Cooper Kupp  LAR  WR  134.0   94.0         2.0         4.0
# 34    DeAndre Hopkins  HOU  WR  150.0  104.0         2.0        18.0
# 1248     Deebo Samuel  SFO  WR  121.0   77.0        59.0       365.0
# 36       Keenan Allen  LAC  WR  149.0  104.0         3.0        16.0
# 38     Allen Robinson  CHI  WR  154.0   98.0         1.0         2.0
# 39     Julian Edelman  NWE  WR  153.0  100.0         8.0        27.0
#
#       RushingTD  ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  \
# 6           0.0        1725.0          9.0         374.60     15  12.400000
# 1247        0.0        1947.0         16.0         295.00     17  11.470588
# 14          0.0        1333.0          9.0         274.10     14   8.714286
# 26          0.0        1394.0          6.0         274.10     15  10.600000
# 25          0.0        1161.0         10.0         270.50     14   9.714286
# 34          0.0        1165.0          7.0         266.54     15  10.133333
# 1248        8.0        1405.0          6.0         262.00     15  12.000000
# 36          0.0        1199.0          6.0         261.50     16   9.500000
# 38          0.0        1147.0          7.0         254.90     15  10.333333
# 39          0.0        1117.0          6.0         254.28     13  12.384615
#
#       Touchdowns  TotYdsScrm
# 6            9.0      1716.0
# 1247        16.0      1965.0
# 14           9.0      1341.0
# 26           6.0      1391.0
# 25          10.0      1165.0
# 34           7.0      1183.0
# 1248        14.0      1770.0
# 36           6.0      1215.0
# 38           7.0      1149.0
# 39           6.0      1144.0

# %%
# Sorted by Fantasy Production
wrc_df['Production'] = ((df['RushingTD'] + df['ReceivingTD'] + df['RushingYds'] + df['ReceivingYds']) / wr_df['Usage'])
wrc_df.head(10)
# Out:
#              Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  RushingTD  \
# 6    Michael Thomas  NOR  WR  185.0  149.0         1.0        -9.0        0.0
# 14     Chris Godwin  TAM  WR  121.0   86.0         1.0         8.0        0.0
# 19   Kenny Golladay  DET  WR  116.0   65.0         0.0         0.0        0.0
# 25      Cooper Kupp  LAR  WR  134.0   94.0         2.0         4.0        0.0
# 26      Julio Jones  ATL  WR  157.0   99.0         2.0        -3.0        0.0
# 27   DeVante Parker  MIA  WR  128.0   72.0         0.0         0.0        0.0
# 31     Amari Cooper  DAL  WR  119.0   79.0         1.0         6.0        0.0
# 32       Mike Evans  TAM  WR  118.0   67.0         0.0         0.0        0.0
# 33       A.J. Brown  TEN  WR   84.0   52.0         3.0        60.0        1.0
# 34  DeAndre Hopkins  HOU  WR  150.0  104.0         2.0        18.0        0.0
#
#     ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 6         1725.0          9.0         374.60     15  12.400000         9.0
# 14        1333.0          9.0         274.10     14   8.714286         9.0
# 19        1190.0         11.0         248.00     16   7.250000        11.0
# 25        1161.0         10.0         270.50     14   9.714286        10.0
# 26        1394.0          6.0         274.10     15  10.600000         6.0
# 27        1202.0          9.0         246.20     14   9.142857         9.0
# 31        1189.0          8.0         246.50     16   7.500000         8.0
# 32        1157.0          8.0         230.70     13   9.076923         8.0
# 33        1051.0          8.0         217.10     11   7.909091         9.0
# 34        1165.0          7.0         266.54     15  10.133333         7.0
#
#     TotYdsScrm  Production
# 6       1716.0  139.112903
# 14      1341.0  154.918033
# 19      1190.0  165.655172
# 25      1165.0  120.955882
# 26      1391.0  131.792453
# 27      1202.0  132.453125
# 31      1195.0  160.400000
# 32      1157.0  128.347458
# 33      1111.0  141.609195
# 34      1183.0  117.434211

# %%
# Plotting the data
from matplotlib import pyplot as plt

plt.style.use('ggplot')

wrc_df.plot(x='Usage', y='Production', kind='scatter')

# %%
wrc_df.to_csv('data/WR_all')

# %% [markdown]
# # 2019, 2020, 2021 NFL Tight End Data

# %%
# Wide Receiver Featured Columns with Usage Ranking and Total Yards From Scrimmage
te_df = main_df.loc[df['Pos'] == 'TE', ['Player', 'Team', 'Pos','Tgt', 'Rec','RushingAtt', 'RushingYds', 'RushingTD', 'ReceivingYds', 'ReceivingTD','FantasyPoints', 'Games',]]
te_df['Usage'] = ((df['Tgt'] + df['RushingAtt']) / main_df['Games'])
te_df['Touchdowns'] = df['RushingTD'] + df['ReceivingTD']
te_df['TotYdsScrm']= df['ReceivingYds']+ df['RushingYds']
te_df.head(10)
# Out:
#             Player Team Pos    Tgt   Rec  RushingAtt  RushingYds  RushingTD  \
# 7     Travis Kelce  KAN  TE  136.0  97.0         1.0         4.0        1.0
# 12    Mark Andrews  BAL  TE   98.0  64.0         0.0         0.0        0.0
# 15   George Kittle  SFO  TE  107.0  85.0         5.0        22.0        0.0
# 18   Darren Waller  OAK  TE  117.0  90.0         2.0         5.0        0.0
# 21       Zach Ertz  PHI  TE  135.0  88.0         0.0         0.0        0.0
# 24      Jared Cook  NOR  TE   65.0  43.0         0.0         0.0        0.0
# 30   Austin Hooper  ATL  TE   97.0  75.0         0.0         0.0        0.0
# 53    Hunter Henry  LAC  TE   76.0  55.0         0.0         0.0        0.0
# 56    Tyler Higbee  LAR  TE   89.0  69.0         0.0         0.0        0.0
# 61  Dallas Goedert  PHI  TE   87.0  58.0         0.0         0.0        0.0
#
#     ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 7         1229.0          5.0          254.3     16   8.562500         6.0
# 12         852.0         10.0          207.2      4  24.500000        10.0
# 15        1053.0          5.0          222.5     14   8.000000         5.0
# 18        1145.0          3.0          221.0     16   7.437500         3.0
# 21         916.0          6.0          213.6     15   9.000000         6.0
# 24         705.0          9.0          167.5      7   9.285714         9.0
# 30         787.0          6.0          189.7     10   9.700000         6.0
# 53         652.0          5.0          148.2     12   6.333333         5.0
# 56         734.0          3.0          160.4     15   5.933333         3.0
# 61         607.0          5.0          144.7      9   9.666667         5.0
#
#     TotYdsScrm
# 7       1233.0
# 12       852.0
# 15      1075.0
# 18      1150.0
# 21       916.0
# 24       705.0
# 30       787.0
# 53       652.0
# 56       734.0
# 61       607.0

# %%
# Cleaned TE df dropping na and nan values
tec_df = te_df.dropna(thresh=2, axis=1)
tec_df.head(10)
# Out:
#             Player Team Pos    Tgt   Rec  RushingAtt  RushingYds  RushingTD  \
# 7     Travis Kelce  KAN  TE  136.0  97.0         1.0         4.0        1.0
# 12    Mark Andrews  BAL  TE   98.0  64.0         0.0         0.0        0.0
# 15   George Kittle  SFO  TE  107.0  85.0         5.0        22.0        0.0
# 18   Darren Waller  OAK  TE  117.0  90.0         2.0         5.0        0.0
# 21       Zach Ertz  PHI  TE  135.0  88.0         0.0         0.0        0.0
# 24      Jared Cook  NOR  TE   65.0  43.0         0.0         0.0        0.0
# 30   Austin Hooper  ATL  TE   97.0  75.0         0.0         0.0        0.0
# 53    Hunter Henry  LAC  TE   76.0  55.0         0.0         0.0        0.0
# 56    Tyler Higbee  LAR  TE   89.0  69.0         0.0         0.0        0.0
# 61  Dallas Goedert  PHI  TE   87.0  58.0         0.0         0.0        0.0
#
#     ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 7         1229.0          5.0          254.3     16   8.562500         6.0
# 12         852.0         10.0          207.2      4  24.500000        10.0
# 15        1053.0          5.0          222.5     14   8.000000         5.0
# 18        1145.0          3.0          221.0     16   7.437500         3.0
# 21         916.0          6.0          213.6     15   9.000000         6.0
# 24         705.0          9.0          167.5      7   9.285714         9.0
# 30         787.0          6.0          189.7     10   9.700000         6.0
# 53         652.0          5.0          148.2     12   6.333333         5.0
# 56         734.0          3.0          160.4     15   5.933333         3.0
# 61         607.0          5.0          144.7      9   9.666667         5.0
#
#     TotYdsScrm
# 7       1233.0
# 12       852.0
# 15      1075.0
# 18      1150.0
# 21       916.0
# 24       705.0
# 30       787.0
# 53       652.0
# 56       734.0
# 61       607.0

# %%
# Sorted by Fantasy Production
tec_df['Production'] = ((df['RushingTD'] + df['ReceivingTD'] + df['RushingYds'] + df['ReceivingYds']) / te_df['Usage'])
tec_df.head(10)
# Out:
#             Player Team Pos    Tgt   Rec  RushingAtt  RushingYds  RushingTD  \
# 7     Travis Kelce  KAN  TE  136.0  97.0         1.0         4.0        1.0
# 12    Mark Andrews  BAL  TE   98.0  64.0         0.0         0.0        0.0
# 15   George Kittle  SFO  TE  107.0  85.0         5.0        22.0        0.0
# 18   Darren Waller  OAK  TE  117.0  90.0         2.0         5.0        0.0
# 21       Zach Ertz  PHI  TE  135.0  88.0         0.0         0.0        0.0
# 24      Jared Cook  NOR  TE   65.0  43.0         0.0         0.0        0.0
# 30   Austin Hooper  ATL  TE   97.0  75.0         0.0         0.0        0.0
# 53    Hunter Henry  LAC  TE   76.0  55.0         0.0         0.0        0.0
# 56    Tyler Higbee  LAR  TE   89.0  69.0         0.0         0.0        0.0
# 61  Dallas Goedert  PHI  TE   87.0  58.0         0.0         0.0        0.0
#
#     ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 7         1229.0          5.0          254.3     16   8.562500         6.0
# 12         852.0         10.0          207.2      4  24.500000        10.0
# 15        1053.0          5.0          222.5     14   8.000000         5.0
# 18        1145.0          3.0          221.0     16   7.437500         3.0
# 21         916.0          6.0          213.6     15   9.000000         6.0
# 24         705.0          9.0          167.5      7   9.285714         9.0
# 30         787.0          6.0          189.7     10   9.700000         6.0
# 53         652.0          5.0          148.2     12   6.333333         5.0
# 56         734.0          3.0          160.4     15   5.933333         3.0
# 61         607.0          5.0          144.7      9   9.666667         5.0
#
#     TotYdsScrm  Production
# 7       1233.0  144.700730
# 12       852.0   35.183673
# 15      1075.0  135.000000
# 18      1150.0  155.025210
# 21       916.0  102.444444
# 24       705.0   76.892308
# 30       787.0   81.752577
# 53       652.0  103.736842
# 56       734.0  124.213483
# 61       607.0   63.310345

# %%
# Sorted by Average Draft Position
tec_df.sort_values(by='FantasyPoints', ascending=False).head(10)
# Out:
#              Player Team Pos    Tgt    Rec  RushingAtt  RushingYds  RushingTD  \
# 7      Travis Kelce  KAN  TE  136.0   97.0         1.0         4.0        1.0
# 15    George Kittle  SFO  TE  107.0   85.0         5.0        22.0        0.0
# 18    Darren Waller  OAK  TE  117.0   90.0         2.0         5.0        0.0
# 21        Zach Ertz  PHI  TE  135.0   88.0         0.0         0.0        0.0
# 623    Travis Kelce  KAN  TE  145.0  105.0         0.0         0.0        0.0
# 12     Mark Andrews  BAL  TE   98.0   64.0         0.0         0.0        0.0
# 1253   Mark Andrews  BAL  TE  153.0  107.0         1.0         0.0        0.0
# 30    Austin Hooper  ATL  TE   97.0   75.0         0.0         0.0        0.0
# 633   Darren Waller  LVR  TE  145.0  107.0         0.0         0.0        0.0
# 1260   Travis Kelce  KAN  TE  134.0   92.0         2.0         3.0        1.0
#
#       ReceivingYds  ReceivingTD  FantasyPoints  Games      Usage  Touchdowns  \
# 7           1229.0          5.0          254.3     16   8.562500         6.0
# 15          1053.0          5.0          222.5     14   8.000000         5.0
# 18          1145.0          3.0          221.0     16   7.437500         3.0
# 21           916.0          6.0          213.6     15   9.000000         6.0
# 623         1416.0         11.0          208.0     15   9.666667        11.0
# 12           852.0         10.0          207.2      4  24.500000        10.0
# 1253        1361.0          9.0          194.0      9  17.111111         9.0
# 30           787.0          6.0          189.7     10   9.700000         6.0
# 633         1196.0          9.0          172.0     15   9.666667         9.0
# 1260        1125.0          9.0          171.0     16   8.500000        10.0
#
#       TotYdsScrm  Production
# 7         1233.0  144.700730
# 15        1075.0  135.000000
# 18        1150.0  155.025210
# 21         916.0  102.444444
# 623       1416.0  147.620690
# 12         852.0   35.183673
# 1253      1361.0   80.064935
# 30         787.0   81.752577
# 633       1196.0  124.655172
# 1260      1128.0  133.882353

# %%
# Plotting the data
from matplotlib import pyplot as plt

plt.style.use('ggplot')

tec_df.plot(x='Usage', y='Production', kind='scatter')

# %%
tec_df.to_csv('data/TE_all')

# %%
# merging two csv files
master_df = pd.concat(
    map(pd.read_csv, ['data/WR_all', 'data/RB_all', 'data/TE_all']), ignore_index=True)

# %%
master_df.head(100)
# Out:
#     Unnamed: 0            Player Team Pos    Tgt    Rec  RushingAtt  \
# 0            6    Michael Thomas  NOR  WR  185.0  149.0         1.0
# 1           14      Chris Godwin  TAM  WR  121.0   86.0         1.0
# 2           19    Kenny Golladay  DET  WR  116.0   65.0         0.0
# 3           25       Cooper Kupp  LAR  WR  134.0   94.0         2.0
# 4           26       Julio Jones  ATL  WR  157.0   99.0         2.0
# ..         ...               ...  ...  ..    ...    ...         ...
# 95         251      Seth Roberts  BAL  WR   35.0   21.0         0.0
# 96         254      Miles Boykin  BAL  WR   22.0   13.0         0.0
# 97         258     Kelvin Harmon  WAS  WR   44.0   30.0         0.0
# 98         259   Paul Richardson  WAS  WR   42.0   28.0         1.0
# 99         260  DaeSean Hamilton  DEN  WR   52.0   28.0         0.0
#
#     RushingYds  RushingTD  ReceivingYds  ReceivingTD  FantasyPoints  Games  \
# 0         -9.0        0.0        1725.0          9.0         374.60     15
# 1          8.0        0.0        1333.0          9.0         274.10     14
# 2          0.0        0.0        1190.0         11.0         248.00     16
# 3          4.0        0.0        1161.0         10.0         270.50     14
# 4         -3.0        0.0        1394.0          6.0         274.10     15
# ..         ...        ...           ...          ...            ...    ...
# 95         0.0        0.0         271.0          2.0          60.10      0
# 96         0.0        0.0         198.0          3.0          50.80     11
# 97         0.0        0.0         365.0          0.0          66.94      8
# 98         0.0        0.0         245.0          2.0          64.50      6
# 99         0.0        0.0         297.0          1.0          63.70      2
#
#         Usage  Touchdowns  TotYdsScrm  Production
# 0   12.400000         9.0      1716.0  139.112903
# 1    8.714286         9.0      1341.0  154.918033
# 2    7.250000        11.0      1190.0  165.655172
# 3    9.714286        10.0      1165.0  120.955882
# 4   10.600000         6.0      1391.0  131.792453
# ..        ...         ...         ...         ...
# 95        inf         2.0       271.0    0.000000
# 96   2.000000         3.0       198.0  100.500000
# 97   5.500000         0.0       365.0   66.363636
# 98   7.166667         2.0       245.0   34.465116
# 99  26.000000         1.0       297.0   11.461538
#
# [100 rows x 17 columns]

# %%
# Shape is just an attribute that tells us the shape of our DataFrame in the format (rows, columns)
print(df.shape) 
print('We have', df.shape[0], 'players we can analyze for all seasons')
print('We have', df.shape[1], 'columns of data we can analyze for all seasons')
# Out:
# (1917, 23)
# We have 1917 players we can analyze for all seasons
# We have 23 columns of data we can analyze for all seasons

# %%
master_df.to_csv('data/Skill_Model.csv')
